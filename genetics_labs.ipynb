# %%
import random 
import pandas as pd
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9900\807886101.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
GENES = []
POPULATION_SIZE = 100
check_list = []

# %%
labs_df = pd.read_csv("labs_data.csv")

labs_df
# Out:
#    Course ID                                      Course Name  Credit Hour  \
# 0     CS101L                             Computing and AI Lab            1
# 1     CS101L                             Computing and AI Lab            1
# 2     CS101L                             Computing and AI Lab            1
# 3     CS101L                             Computing and AI Lab            1
# 4     CS101L                             Computing and AI Lab            1
# 5     CS101L                             Computing and AI Lab            1
# 6     CS101L                             Computing and AI Lab            1
# 7     CS101L                             Computing and AI Lab            1
# 8     CS101L                             Computing and AI Lab            1
# 9     CS101L                             Computing and AI Lab            1
# 10    CS101L                             Computing and AI Lab            1
# 11    CS101L                             Computing and AI Lab            1
# 12    CS101L                             Computing and AI Lab            1
# 13    CS101L                             Computing and AI Lab            1
# 14    CS232L                  Database Management Systems Lab            1
# 15    CS232L                  Database Management Systems Lab            1
# 16    CS232L                  Database Management Systems Lab            1
# 17    CS232L                  Database Management Systems Lab            1
# 18    CS232L                  Database Management Systems Lab            1
# 19    CE231L                                Electronics I Lab            1
# 20    CS251L                      Artificial Intelligence Lab            1
# 21    CS351L                      Artificial Intelligence Lab            1
# 22    CE222L  Computer Organization and Assembly Language Lab            1
# 23    CE222L  Computer Organization and Assembly Language Lab            1
# 24    CE222L  Computer Organization and Assembly Language Lab            1
# 25    DS351L                           Data Visualization Lab            1
# 26    AI319L                              Computer Vision Lab            1
# 27    CE221L                         Digital Logic Design Lab            3
# 28    CE221L                         Digital Logic Design Lab            3
# 29    CS112L       Object Oriented Programming and Design Lab            1
# 30    CS112L       Object Oriented Programming and Design Lab            1
# 31    CS112L       Object Oriented Programming and Design Lab            1
# 32    CS112L       Object Oriented Programming and Design Lab            1
# 33    CS112L       Object Oriented Programming and Design Lab            1
# 34    CS112L       Object Oriented Programming and Design Lab            1
# 35    CS112L       Object Oriented Programming and Design Lab            1
# 36    CS112L       Object Oriented Programming and Design Lab            1
# 37    CS112L       Object Oriented Programming and Design Lab            1
# 38    CS112L       Object Oriented Programming and Design Lab            1
# 39    CS112L       Object Oriented Programming and Design Lab            1
# 40    CS112L       Object Oriented Programming and Design Lab            1
# 41    CS112L       Object Oriented Programming and Design Lab            1
# 42    AI202L                  Trends and Techniques in AI Lab            1
# 43    CS312L                           System Programming Lab            1
# 44    CS312L                           System Programming Lab            1
#
#     Semester of Student Section      Type
# 0                     2       A  Software
# 1                     2       B  Software
# 2                     2       C  Software
# 3                     2       D  Software
# 4                     2       E  Software
# 5                     2       F  Software
# 6                     2       G  Software
# 7                     2       H  Software
# 8                     2       I  Software
# 9                     2       J  Software
# 10                    2       K  Software
# 11                    2       L  Software
# 12                    2       M  Software
# 13                    2       N  Software
# 14                    4       A    SE LAB
# 15                    4       B    SE LAB
# 16                    4       C    SE LAB
# 17                    4       D    SE LAB
# 18                    4       E    SE LAB
# 19                    4       B    SA LAB
# 20                    4       E    AI LAB
# 21                    6       C    AI LAB
# 22                    4       A  Hardware
# 23                    4       D  Hardware
# 24                    4       E  Hardware
# 25                    6       D  Software
# 26                    6       A    AI LAB
# 27                    3       C   DLD LAB
# 28                    3       B   DLD LAB
# 29                    2       A  Software
# 30                    2       B  Software
# 31                    2       C  Software
# 32                    2       D  Software
# 33                    2       E  Software
# 34                    2       F  Software
# 35                    2       G  Software
# 36                    2       H  Software
# 37                    2       I  Software
# 38                    2       J  Software
# 39                    2       K  Software
# 40                    2       L  Software
# 41                    2       M  Software
# 42                    4       A    AI LAB
# 43                    6       C  Software
# 44                    6       B  Software

# %%
# Split the DataFrame based on the 'Type' column
grouped = labs_df.groupby('Type')

# Create separate DataFrames for each type
tables = {type_name: group.reset_index(drop=True) for type_name, group in grouped}

tables
# Out:
# {'AI LAB':   Course ID                      Course Name  Credit Hour  \
#  0    CS251L      Artificial Intelligence Lab            1
#  1    CS351L      Artificial Intelligence Lab            1
#  2    AI319L              Computer Vision Lab            1
#  3    AI202L  Trends and Techniques in AI Lab            1
#
#     Semester of Student Section    Type
#  0                    4       E  AI LAB
#  1                    6       C  AI LAB
#  2                    6       A  AI LAB
#  3                    4       A  AI LAB  ,
#  'DLD LAB':   Course ID               Course Name  Credit Hour  Semester of Student  \
#  0    CE221L  Digital Logic Design Lab            3                    3
#  1    CE221L  Digital Logic Design Lab            3                    3
#
#    Section     Type
#  0       C  DLD LAB
#  1       B  DLD LAB  ,
#  'Hardware':   Course ID                                      Course Name  Credit Hour  \
#  0    CE222L  Computer Organization and Assembly Language Lab            1
#  1    CE222L  Computer Organization and Assembly Language Lab            1
#  2    CE222L  Computer Organization and Assembly Language Lab            1
#
#     Semester of Student Section      Type
#  0                    4       A  Hardware
#  1                    4       D  Hardware
#  2                    4       E  Hardware  ,
#  'SA LAB':   Course ID        Course Name  Credit Hour  Semester of Student Section  \
#  0    CE231L  Electronics I Lab            1                    4       B
#
#       Type
#  0  SA LAB  ,
#  'SE LAB':   Course ID                      Course Name  Credit Hour  \
#  0    CS232L  Database Management Systems Lab            1
#  1    CS232L  Database Management Systems Lab            1
#  2    CS232L  Database Management Systems Lab            1
#  3    CS232L  Database Management Systems Lab            1
#  4    CS232L  Database Management Systems Lab            1
#
#     Semester of Student Section    Type
#  0                    4       A  SE LAB
#  1                    4       B  SE LAB
#  2                    4       C  SE LAB
#  3                    4       D  SE LAB
#  4                    4       E  SE LAB  ,
#  'Software':    Course ID                                 Course Name  Credit Hour  \
#  0     CS101L                        Computing and AI Lab            1
#  1     CS101L                        Computing and AI Lab            1
#  2     CS101L                        Computing and AI Lab            1
#  3     CS101L                        Computing and AI Lab            1
#  4     CS101L                        Computing and AI Lab            1
#  5     CS101L                        Computing and AI Lab            1
#  6     CS101L                        Computing and AI Lab            1
#  7     CS101L                        Computing and AI Lab            1
#  8     CS101L                        Computing and AI Lab            1
#  9     CS101L                        Computing and AI Lab            1
#  10    CS101L                        Computing and AI Lab            1
#  11    CS101L                        Computing and AI Lab            1
#  12    CS101L                        Computing and AI Lab            1
#  13    CS101L                        Computing and AI Lab            1
#  14    DS351L                      Data Visualization Lab            1
#  15    CS112L  Object Oriented Programming and Design Lab            1
#  16    CS112L  Object Oriented Programming and Design Lab            1
#  17    CS112L  Object Oriented Programming and Design Lab            1
#  18    CS112L  Object Oriented Programming and Design Lab            1
#  19    CS112L  Object Oriented Programming and Design Lab            1
#  20    CS112L  Object Oriented Programming and Design Lab            1
#  21    CS112L  Object Oriented Programming and Design Lab            1
#  22    CS112L  Object Oriented Programming and Design Lab            1
#  23    CS112L  Object Oriented Programming and Design Lab            1
#  24    CS112L  Object Oriented Programming and Design Lab            1
#  25    CS112L  Object Oriented Programming and Design Lab            1
#  26    CS112L  Object Oriented Programming and Design Lab            1
#  27    CS112L  Object Oriented Programming and Design Lab            1
#  28    CS312L                      System Programming Lab            1
#  29    CS312L                      System Programming Lab            1
#
#      Semester of Student Section      Type
#  0                     2       A  Software
#  1                     2       B  Software
#  2                     2       C  Software
#  3                     2       D  Software
#  4                     2       E  Software
#  5                     2       F  Software
#  6                     2       G  Software
#  7                     2       H  Software
#  8                     2       I  Software
#  9                     2       J  Software
#  10                    2       K  Software
#  11                    2       L  Software
#  12                    2       M  Software
#  13                    2       N  Software
#  14                    6       D  Software
#  15                    2       A  Software
#  16                    2       B  Software
#  17                    2       C  Software
#  18                    2       D  Software
#  19                    2       E  Software
#  20                    2       F  Software
#  21                    2       G  Software
#  22                    2       H  Software
#  23                    2       I  Software
#  24                    2       J  Software
#  25                    2       K  Software
#  26                    2       L  Software
#  27                    2       M  Software
#  28                    6       C  Software
#  29                    6       B  Software  }

# %%
labs = ['hardware', 'software', 'ai lab', 'dld lab', 'sa lab']

# %%
schedule = {
    'monday': {
        'hardware': ["", ""], 
        'software': ["", ""], 
        'ai lab': ["", ""], 
        'dld lab': ["", ""], 
        'sa lab': ["", ""]
    },
    'tuesday': {
        'hardware': ["", ""], 
        'software': ["", ""], 
        'ai lab': ["", ""], 
        'dld lab': ["", ""], 
        'sa lab': ["", ""]
    },
    'wednesday': {
        'hardware': ["", ""], 
        'software': ["", ""], 
        'ai lab': ["", ""], 
        'dld lab': ["", ""], 
        'sa lab': ["", ""]
    },
    'thursday': {
        'hardware': ["", ""], 
        'software': ["", ""], 
        'ai lab': ["", ""], 
        'dld lab': ["", ""], 
        'sa lab': ["", ""]
    },
    'friday': {
        'hardware': ["", ""], 
        'software': ["", ""], 
        'ai lab': ["", ""], 
        'dld lab': ["", ""], 
        'sa lab': ["", ""]
    }
}

# Example access
print(schedule['monday']['hardware'])  # Output: ["", ""]
# Out:
# ['', '']

# %%
class Individual(object):
     
	''' 
	Class representing individual in population 
	'''
	def __init__(self, chromosome,day): 
		self.chromosome = chromosome 
		self.fitness = self.cal_fitness(day) 

	@classmethod
	def mutated_genes(self): 
		''' 
		create random genes for mutation 
		'''
		global GENES 
		gene = random.choice(GENES) 
		return gene 

	@classmethod
	def create_gnome(self): 
		''' 
		create chromosome or string of genes 
		'''
		gnome_len = 2
		return [self.mutated_genes() for _ in range(gnome_len)] 

	def mate(self, par2,day): 
		''' 
		Perform mating and produce new offspring 
		'''

		# chromosome for offspring 
		child_chromosome = [] 
		for gp1, gp2 in zip(self.chromosome, par2.chromosome):	 

			# random probability 
			prob = random.random() 

			# if prob is less than 0.45, insert gene 
			# from parent 1 
			if prob < 0.45: 
				child_chromosome.append(gp1) 

			# if prob is between 0.45 and 0.90, insert 
			# gene from parent 2 
			elif prob < 0.90: 
				child_chromosome.append(gp2) 

			# otherwise insert random gene(mutate), 
			# for maintaining diversity 
			else: 
				child_chromosome.append(self.mutated_genes()) 

		# create new Individual(offspring) using 
		# generated chromosome for offspring 
		return Individual(child_chromosome,day) 

	def cal_fitness(self,day):
         fitness = 0
         global check_list
         # Reducing same day clash
         if self.chromosome[0] == self.chromosome[1]:
             fitness += 1
         # Reducing Clashes
         # Credit hour issue resolve
         for i in range(len(self.chromosome)):
             if self.chromosome[i] in check_list:
                 fitness += 1
             for j in range(len(labs)):
                 if self.chromosome[i] == schedule[day][labs[j]]:
                     fitness += 1
          
         return fitness

# %%
# Driver code 
def main(): 
    global POPULATION_SIZE 
    global GENES
    global check_list
    for labs in tables:
        print(len(labs))
        k = labs.lower()
        #print(k)
        GENES = []
        check_list = []
        t = len(labs)
        if len(labs)%2 != 0:
            t += 1
        for i in range(t):
            GENES.append(i)
        days = ['monday', 'tuesday', 'wednesday', 'thursday', 'friday']
        generation = 1
        population = []
        day = 0 
        for _ in range(POPULATION_SIZE): 
            gnome = Individual.create_gnome() 
            population.append(Individual(gnome,days[day]))
        check = 0
        while check != len(labs):
            #print("hello") 
            population = sorted(population, key = lambda x:x.fitness)
            if population[0].fitness <= 0:
                print(k)
                schedule[days[day]][k] = population[0].chromosome
                check_list.append(population[0].chromosome)
                check_list = [item for sublist in check_list for item in (sublist if isinstance(sublist, list) else [sublist])]
                if day == 4:
                    day = 0
                day = day + 1
                 
                check += 2
                print(schedule)
                if check == t:
                    print("HEllo")
                    break
            new_generation = [] 
            # s = int((10*POPULATION_SIZE)/100) 
            # new_generation.extend(population[:s]) 
            
            s = int((100*POPULATION_SIZE)/100) 
            for _ in range(s): 
                parent1 = random.choice(population[:50]) 
                parent2 = random.choice(population[:50]) 
                child = parent1.mate(parent2,days[day]) 
                new_generation.append(child) 
            population = new_generation
            for i in population:
                Individual(i.chromosome,days[day])
            #print(check_list)
            
            generation += 1
        print("ddddddddddddddddd")
        day = day + 1 


	# print("Generation: {}\tString: {}\tFitness: {}".format(
	# 	generation, 
	# 	"".join(population[0].chromosome), 
	# 	population[0].fitness))

# %%
print(schedule)
# Out:
# {'monday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}, 'tuesday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}, 'wednesday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}, 'thursday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}, 'friday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}}

# %%
if __name__ == '__main__': 
	main()
# Out:
# 6
# ai lab
# {'monday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': [2, 5], 'dld lab': ['', ''], 'sa lab': ['', '']}, 'tuesday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}, 'wednesday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}, 'thursday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}, 'friday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}}
# ai lab
# {'monday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': [2, 5], 'dld lab': ['', ''], 'sa lab': ['', '']}, 'tuesday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': [4, 1], 'dld lab': ['', ''], 'sa lab': ['', '']}, 'wednesday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}, 'thursday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}, 'friday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}}
# ai lab
# {'monday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': [2, 5], 'dld lab': ['', ''], 'sa lab': ['', '']}, 'tuesday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': [4, 1], 'dld lab': ['', ''], 'sa lab': ['', '']}, 'wednesday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': [3, 0], 'dld lab': ['', ''], 'sa lab': ['', '']}, 'thursday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}, 'friday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}}
# HEllo
# ddddddddddddddddd
# 7
# dld lab
# {'monday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': [2, 5], 'dld lab': [4, 1], 'sa lab': ['', '']}, 'tuesday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': [4, 1], 'dld lab': ['', ''], 'sa lab': ['', '']}, 'wednesday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': [3, 0], 'dld lab': ['', ''], 'sa lab': ['', '']}, 'thursday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}, 'friday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}}
# dld lab
# {'monday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': [2, 5], 'dld lab': [4, 1], 'sa lab': ['', '']}, 'tuesday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': [4, 1], 'dld lab': [7, 6], 'sa lab': ['', '']}, 'wednesday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': [3, 0], 'dld lab': ['', ''], 'sa lab': ['', '']}, 'thursday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}, 'friday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}}
# dld lab
# {'monday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': [2, 5], 'dld lab': [4, 1], 'sa lab': ['', '']}, 'tuesday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': [4, 1], 'dld lab': [7, 6], 'sa lab': ['', '']}, 'wednesday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': [3, 0], 'dld lab': [0, 3], 'sa lab': ['', '']}, 'thursday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}, 'friday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}}
# dld lab
# {'monday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': [2, 5], 'dld lab': [4, 1], 'sa lab': ['', '']}, 'tuesday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': [4, 1], 'dld lab': [7, 6], 'sa lab': ['', '']}, 'wednesday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': [3, 0], 'dld lab': [0, 3], 'sa lab': ['', '']}, 'thursday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': [2, 5], 'sa lab': ['', '']}, 'friday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}}
# HEllo
# ddddddddddddddddd
# 8
# hardware
# {'monday': {'hardware': [5, 7], 'software': ['', ''], 'ai lab': [2, 5], 'dld lab': [4, 1], 'sa lab': ['', '']}, 'tuesday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': [4, 1], 'dld lab': [7, 6], 'sa lab': ['', '']}, 'wednesday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': [3, 0], 'dld lab': [0, 3], 'sa lab': ['', '']}, 'thursday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': [2, 5], 'sa lab': ['', '']}, 'friday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}}
# hardware
# {'monday': {'hardware': [5, 7], 'software': ['', ''], 'ai lab': [2, 5], 'dld lab': [4, 1], 'sa lab': ['', '']}, 'tuesday': {'hardware': [2, 3], 'software': ['', ''], 'ai lab': [4, 1], 'dld lab': [7, 6], 'sa lab': ['', '']}, 'wednesday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': [3, 0], 'dld lab': [0, 3], 'sa lab': ['', '']}, 'thursday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': [2, 5], 'sa lab': ['', '']}, 'friday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}}
# hardware
# {'monday': {'hardware': [5, 7], 'software': ['', ''], 'ai lab': [2, 5], 'dld lab': [4, 1], 'sa lab': ['', '']}, 'tuesday': {'hardware': [2, 3], 'software': ['', ''], 'ai lab': [4, 1], 'dld lab': [7, 6], 'sa lab': ['', '']}, 'wednesday': {'hardware': [6, 4], 'software': ['', ''], 'ai lab': [3, 0], 'dld lab': [0, 3], 'sa lab': ['', '']}, 'thursday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': [2, 5], 'sa lab': ['', '']}, 'friday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}}
# hardware
# {'monday': {'hardware': [5, 7], 'software': ['', ''], 'ai lab': [2, 5], 'dld lab': [4, 1], 'sa lab': ['', '']}, 'tuesday': {'hardware': [2, 3], 'software': ['', ''], 'ai lab': [4, 1], 'dld lab': [7, 6], 'sa lab': ['', '']}, 'wednesday': {'hardware': [6, 4], 'software': ['', ''], 'ai lab': [3, 0], 'dld lab': [0, 3], 'sa lab': ['', '']}, 'thursday': {'hardware': [0, 1], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': [2, 5], 'sa lab': ['', '']}, 'friday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}}
# HEllo
# ddddddddddddddddd
# 6
# sa lab
# {'monday': {'hardware': [5, 7], 'software': ['', ''], 'ai lab': [2, 5], 'dld lab': [4, 1], 'sa lab': [0, 2]}, 'tuesday': {'hardware': [2, 3], 'software': ['', ''], 'ai lab': [4, 1], 'dld lab': [7, 6], 'sa lab': ['', '']}, 'wednesday': {'hardware': [6, 4], 'software': ['', ''], 'ai lab': [3, 0], 'dld lab': [0, 3], 'sa lab': ['', '']}, 'thursday': {'hardware': [0, 1], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': [2, 5], 'sa lab': ['', '']}, 'friday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}}
# sa lab
# {'monday': {'hardware': [5, 7], 'software': ['', ''], 'ai lab': [2, 5], 'dld lab': [4, 1], 'sa lab': [0, 2]}, 'tuesday': {'hardware': [2, 3], 'software': ['', ''], 'ai lab': [4, 1], 'dld lab': [7, 6], 'sa lab': [1, 3]}, 'wednesday': {'hardware': [6, 4], 'software': ['', ''], 'ai lab': [3, 0], 'dld lab': [0, 3], 'sa lab': ['', '']}, 'thursday': {'hardware': [0, 1], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': [2, 5], 'sa lab': ['', '']}, 'friday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}}
# sa lab
# {'monday': {'hardware': [5, 7], 'software': ['', ''], 'ai lab': [2, 5], 'dld lab': [4, 1], 'sa lab': [0, 2]}, 'tuesday': {'hardware': [2, 3], 'software': ['', ''], 'ai lab': [4, 1], 'dld lab': [7, 6], 'sa lab': [1, 3]}, 'wednesday': {'hardware': [6, 4], 'software': ['', ''], 'ai lab': [3, 0], 'dld lab': [0, 3], 'sa lab': [4, 5]}, 'thursday': {'hardware': [0, 1], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': [2, 5], 'sa lab': ['', '']}, 'friday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}}
# HEllo
# ddddddddddddddddd
# 6
# se lab
# {'monday': {'hardware': [5, 7], 'software': ['', ''], 'ai lab': [2, 5], 'dld lab': [4, 1], 'sa lab': [0, 2], 'se lab': [0, 4]}, 'tuesday': {'hardware': [2, 3], 'software': ['', ''], 'ai lab': [4, 1], 'dld lab': [7, 6], 'sa lab': [1, 3]}, 'wednesday': {'hardware': [6, 4], 'software': ['', ''], 'ai lab': [3, 0], 'dld lab': [0, 3], 'sa lab': [4, 5]}, 'thursday': {'hardware': [0, 1], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': [2, 5], 'sa lab': ['', '']}, 'friday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}}
# se lab
# {'monday': {'hardware': [5, 7], 'software': ['', ''], 'ai lab': [2, 5], 'dld lab': [4, 1], 'sa lab': [0, 2], 'se lab': [0, 4]}, 'tuesday': {'hardware': [2, 3], 'software': ['', ''], 'ai lab': [4, 1], 'dld lab': [7, 6], 'sa lab': [1, 3], 'se lab': [3, 2]}, 'wednesday': {'hardware': [6, 4], 'software': ['', ''], 'ai lab': [3, 0], 'dld lab': [0, 3], 'sa lab': [4, 5]}, 'thursday': {'hardware': [0, 1], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': [2, 5], 'sa lab': ['', '']}, 'friday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}}
# se lab
# {'monday': {'hardware': [5, 7], 'software': ['', ''], 'ai lab': [2, 5], 'dld lab': [4, 1], 'sa lab': [0, 2], 'se lab': [0, 4]}, 'tuesday': {'hardware': [2, 3], 'software': ['', ''], 'ai lab': [4, 1], 'dld lab': [7, 6], 'sa lab': [1, 3], 'se lab': [3, 2]}, 'wednesday': {'hardware': [6, 4], 'software': ['', ''], 'ai lab': [3, 0], 'dld lab': [0, 3], 'sa lab': [4, 5], 'se lab': [1, 5]}, 'thursday': {'hardware': [0, 1], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': [2, 5], 'sa lab': ['', '']}, 'friday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}}
# HEllo
# ddddddddddddddddd
# 8
# software
# {'monday': {'hardware': [5, 7], 'software': [5, 0], 'ai lab': [2, 5], 'dld lab': [4, 1], 'sa lab': [0, 2], 'se lab': [0, 4]}, 'tuesday': {'hardware': [2, 3], 'software': ['', ''], 'ai lab': [4, 1], 'dld lab': [7, 6], 'sa lab': [1, 3], 'se lab': [3, 2]}, 'wednesday': {'hardware': [6, 4], 'software': ['', ''], 'ai lab': [3, 0], 'dld lab': [0, 3], 'sa lab': [4, 5], 'se lab': [1, 5]}, 'thursday': {'hardware': [0, 1], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': [2, 5], 'sa lab': ['', '']}, 'friday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}}
# software
# {'monday': {'hardware': [5, 7], 'software': [5, 0], 'ai lab': [2, 5], 'dld lab': [4, 1], 'sa lab': [0, 2], 'se lab': [0, 4]}, 'tuesday': {'hardware': [2, 3], 'software': [3, 4], 'ai lab': [4, 1], 'dld lab': [7, 6], 'sa lab': [1, 3], 'se lab': [3, 2]}, 'wednesday': {'hardware': [6, 4], 'software': ['', ''], 'ai lab': [3, 0], 'dld lab': [0, 3], 'sa lab': [4, 5], 'se lab': [1, 5]}, 'thursday': {'hardware': [0, 1], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': [2, 5], 'sa lab': ['', '']}, 'friday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}}
# software
# {'monday': {'hardware': [5, 7], 'software': [5, 0], 'ai lab': [2, 5], 'dld lab': [4, 1], 'sa lab': [0, 2], 'se lab': [0, 4]}, 'tuesday': {'hardware': [2, 3], 'software': [3, 4], 'ai lab': [4, 1], 'dld lab': [7, 6], 'sa lab': [1, 3], 'se lab': [3, 2]}, 'wednesday': {'hardware': [6, 4], 'software': [1, 7], 'ai lab': [3, 0], 'dld lab': [0, 3], 'sa lab': [4, 5], 'se lab': [1, 5]}, 'thursday': {'hardware': [0, 1], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': [2, 5], 'sa lab': ['', '']}, 'friday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}}
# software
# {'monday': {'hardware': [5, 7], 'software': [5, 0], 'ai lab': [2, 5], 'dld lab': [4, 1], 'sa lab': [0, 2], 'se lab': [0, 4]}, 'tuesday': {'hardware': [2, 3], 'software': [3, 4], 'ai lab': [4, 1], 'dld lab': [7, 6], 'sa lab': [1, 3], 'se lab': [3, 2]}, 'wednesday': {'hardware': [6, 4], 'software': [1, 7], 'ai lab': [3, 0], 'dld lab': [0, 3], 'sa lab': [4, 5], 'se lab': [1, 5]}, 'thursday': {'hardware': [0, 1], 'software': [2, 6], 'ai lab': ['', ''], 'dld lab': [2, 5], 'sa lab': ['', '']}, 'friday': {'hardware': ['', ''], 'software': ['', ''], 'ai lab': ['', ''], 'dld lab': ['', ''], 'sa lab': ['', '']}}
# HEllo
# ddddddddddddddddd
